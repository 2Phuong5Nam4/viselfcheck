# %%
# !git clone https://github.com/2Phuong5Nam4/viselfcheck.git
# Out:
# Cloning into 'viselfcheck'...
# remote: Enumerating objects: 76, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 76 (delta 22), reused 70 (delta 19), pack-reused 0 (from 0)
# Receiving objects: 100% (76/76), 42.56 KiB | 3.27 MiB/s, done.
# Resolving deltas: 100% (22/22), done.

# %%
# Ubuntu/Debian - Install system dependencies
# !sudo add-apt-repository -y ppa:deadsnakes/ppa
# !sudo apt update

# Install Python 3.8 if needed
# Ubuntu/Debian
# !sudo apt install python3.8
# !sudo apt install python3.8-dev python3.8-venv python3.8-distutils
# Out:
# Repository: 'deb https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu/ jammy main'
# Description:
# This PPA contains more recent Python versions packaged for Ubuntu.
#
# Disclaimer: there's no guarantee of timely updates in case of security problems or other issues. If you want to use them in a security-or-otherwise-critical environment (say, on a production server), you do so at your own risk.
#
# Update Note
# ...
# Please use this repository instead of ppa:fkrull/deadsnakes.
#
# Reporting Issues
# ...
#
# Issues can be reported in the master issue tracker at:
# https://github.com/deadsnakes/issues/issues
#
# Supported Ubuntu and Python Versions
# ...
#
# - Ubuntu 20.04 (focal) Python3.5 - Python3.7, Python3.9 - Python3.13
# - Ubuntu 22.04 (jammy) Python3.7 - Python3.9, Python3.11 - Python3.13
# - Ubuntu 24.04 (noble) Python3.7 - Python3.11, Python3.13
# ...

# %%
# !python3.8 --version

# 2. Create virtual environment
# !python3.8 -m venv venv_viselfcheck

# 3. Activate virtual environment
# !source venv_viselfcheck/bin/activate
# Out:
# Python 3.8.20

# %%
# 4. Install package
# %cd /content/viselfcheck/viselfcheck
# !/content/venv_viselfcheck/bin/pip install -e .
# Out:
# /content/viselfcheck/viselfcheck
# Obtaining file:///content/viselfcheck/viselfcheck
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 30.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 64.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 86.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.6/343.6 kB 44.2 MB/s eta 0:00:00
# ...

# %%
# %cd /content/viselfcheck/
# !/content/venv_viselfcheck/bin/python eval/eval_all_methods.py --methods nli ngram  mqag bert_score
# Out:
# /content/viselfcheck
# Using device: cuda
# Cloning dataset from HuggingFace...
# Cloning into 'Vietnamese_Hallucination'...
# remote: Enumerating objects: 6, done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 6 (from 1)
# Unpacking objects: 100% (6/6), 115.49 KiB | 2.75 MiB/s, done.
# Loading dataset from Vietnamese_Hallucination...
# Found CSV file: Vietnamese_Hallucination/Vietnamese_hallucination_annotated_checked - Vietnamese_hallucination_annotated_checked.csv
# Dataset loaded with 40 datapoints
#
# Evaluating methods: ['nli']
#
# ...
# EVALUATING NLI METHOD
# ...
# Evaluating nli method...
# config.json: 100% 924/924 [00:00<00:00, 149kB/s]
# model.safetensors: 100% 1.48G/1.48G [00:08<00:00, 175MB/s]
# tokenizer_config.json: 1.20kB [00:00, 5.52MB/s]
# vocab.txt: 895kB [00:00, 14.8MB/s]
# bpe.codes: 1.14MB [00:00, 81.4MB/s]
# added_tokens.json: 100% 22.0/22.0 [00:00<00:00, 4.07kB/s]
# special_tokens_map.json: 100% 167/167 [00:00<00:00, 102kB/s]
# ...
